# %%
import pandas as pd

# %% [markdown]
# # Direct Marketing Campaigns of Portuguese Banking Clients
# 2 years worth of data (2008-2010).
# 4,119 records.
# 20 independent variables.
# 1 dependent variable.

# %% [markdown]
# **Note from the authors of the dataset:**
# > Missing Attribute Values: There are several missing values in some categorical attributes, all coded with the "unknown" label. These missing values can be treated as a possible class label or using deletion or imputation techniques.
#
# Will define the NA value when reading in the dataset.

# %%
banking_raw = pd.read_csv('./data/bank-original.csv', header=0, sep=";", na_values="unknown")
banking_raw.shape
# Out:
# (4119, 21)

# %%
banking_raw.head().T
# Out:
#                           0            1            2            3  \
# age                      30           39           25           38
# job             blue-collar     services     services     services
# marital             married       single      married      married
# education          basic.9y  high.school  high.school     basic.9y
# default                  no           no           no           no
# housing                 yes           no          yes          NaN
# loan                     no           no           no          NaN
# contact            cellular    telephone    telephone    telephone
# month                   may          may          jun          jun
# day_of_week             fri          fri          wed          fri
# duration                487          346          227           17
# campaign                  2            4            1            3
# pdays                   999          999          999          999
# ...

# %%
banking_raw.describe(include="all")
# Out:
#                 age     job  marital          education default housing  loan  \
# count   4119.000000    4080     4108               3952    3316    4014  4014
# unique          NaN      11        3                  7       2       2     2
# top             NaN  admin.  married  university.degree      no     yes    no
# freq            NaN    1012     2509               1264    3315    2175  3349
# mean      40.113620     NaN      NaN                NaN     NaN     NaN   NaN
# std       10.313362     NaN      NaN                NaN     NaN     NaN   NaN
# min       18.000000     NaN      NaN                NaN     NaN     NaN   NaN
# 25%       32.000000     NaN      NaN                NaN     NaN     NaN   NaN
# 50%       38.000000     NaN      NaN                NaN     NaN     NaN   NaN
# 75%       47.000000     NaN      NaN                NaN     NaN     NaN   NaN
# max       88.000000     NaN      NaN                NaN     NaN     NaN   NaN
#
# ...

# %% [markdown]
# *Please note, according to the dataset description, a client that had not been contacted previously is represented with the value 999 in the "contact" column.*

# %%
banking_raw.isna().sum()

# %% [markdown]
# Will drop all records that contain any null values since we need to reduce our dataset to <= 3,000 records.

# %%
banking_nonulls = banking_raw.dropna(how='any')
banking_nonulls.shape
# Out:
# (3090, 21)

# %%
bank = banking_nonulls

# %% [markdown]
# In summary, we:
# - imported our original 4,119 record dataset
# - defined & identified the null values present
# - removed the rows with any null value present
#
# We will keep the dataset as is (3,090) as permitted by the professor, and will export `banking_nonulls` dataframe to a CSV.

# %%
bank.rename(columns={"emp.var.rate": "emp_var_rate", "cons.price.idx": "cons_price_idx", "cons.conf.idx": "cons_conf_idx", "nr.employed": "nr_employed"}, 
            inplace=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
bank.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp_var_rate', 'cons_price_idx',
#        'cons_conf_idx', 'euribor3m', 'nr_employed', 'y'],
#       dtype='object')

# %%
bank.reset_index(inplace=True, drop=True)

# %%
bank.head(10)
# Out:
#    age            job   marital            education default housing loan  \
# 0   30    blue-collar   married             basic.9y      no     yes   no
# 1   39       services    single          high.school      no      no   no
# 2   25       services   married          high.school      no     yes   no
# 3   47         admin.   married    university.degree      no     yes   no
# 4   32       services    single    university.degree      no      no   no
# 5   32         admin.    single    university.degree      no     yes   no
# 6   31       services  divorced  professional.course      no      no   no
# 7   36  self-employed    single             basic.4y      no      no   no
# 8   36         admin.   married          high.school      no      no   no
# 9   47    blue-collar   married             basic.4y      no     yes   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# ...

# %%
# bank.to_csv('./data/cleaned-bank.csv')

# %% [markdown]
# <font color="red">**NOTE:** Add `i` as the first column name to indicate index. </font> Can do so on the terminal by inputing:
#    - `vi cleaned-bank.csv` to edit the file
#    - `i` to insert text
#    - On first line, enter `i` right before the comma.
#    - `esc`
#    - `:wq` to write changes and quit
#
# Need to do this for SAS code to work.

# %% [markdown]
# # Actual Analysis of Cleaned Dataset

# %%
pd.set_option('display.max_columns', None)

# %%
bank.describe(include="all").T
# Out:
#                count unique                top  freq       mean       std  \
# age             3090    NaN                NaN   NaN    39.1841    10.184
# job             3090     11             admin.   854        NaN       NaN
# marital         3090      3            married  1791        NaN       NaN
# education       3090      7  university.degree  1107        NaN       NaN
# default         3090      2                 no  3089        NaN       NaN
# housing         3090      2                yes  1688        NaN       NaN
# loan            3090      2                 no  2583        NaN       NaN
# contact         3090      2           cellular  2108        NaN       NaN
# month           3090     10                may   981        NaN       NaN
# day_of_week     3090      5                mon   642        NaN       NaN
# duration        3090    NaN                NaN   NaN    259.245    263.96
# campaign        3090    NaN                NaN   NaN    2.50939   2.59817
# ...

# %% [markdown]
# **pdays**
# -	Days passed since previous campaign’s contact.
# -	A client that had not been contacted previously is represented with the value 999.
#
# I interpret a value of 999 as almost equivalent to a N/A value, and a value of 0 as the client being contacted the same day?  Hopefully our model doesn't deem this attribute significant so we don't have to figure out what to do with these value discrepancies (see unique value frequency counts below).

# %%
# frequency/count of each unique value
bank['pdays'].value_counts()
# Out:
# 999    2948
# 3        46
# 6        40
# 4        13
# 10        8
# 7         6
# 12        5
# 2         4
# 5         4
# 1         3
# 0         2
# 15        2
# 9         2
# 13        2
# 18        1
# 16        1
# 21        1
# 11        1
# 19        1
# Name: pdays, dtype: int64

# %%
bank['month'].value_counts()
# Out:
# may    981
# jul    514
# aug    495
# nov    387
# jun    365
# apr    169
# oct     61
# sep     57
# mar     42
# dec     19
# Name: month, dtype: int64

# %% [markdown]
# Month5 (May) was seen as significant in the STEPWISE selection method.  This is biased because it's the month with the most calls.
# Month3 (March) followed as significant.  It has the 2nd lowest frequency (good thing), but it's also the 1st month of the campaign.
# Finally, month6 (June) followed as significant. This month may also be biased because it has the 2nd highest frequency of calls.
#
# The selection method chose 8 out of the 53 attributes, but the R2 value was only 0.2637.

# %% [markdown]
# We have:
# - 2720 samples of 'no' => 88% Probability,
# - and 370 samples of 'yes' => 12% Probability.
#
# odds(y=1) = 0.12/0.88 => The odds that event Y = 1 occurs is 0.136 to 1.  This means we have a higher chance of failure.
#
# odds(y=0) = 0.88/0.12 => 7.33  to 1 	(slide 8 of lecture 7)
#
# I want to test if removing some observations would increase the Rsquare value, specifically observations that meet the following criteria:
#    - target = 0
#    - pdays = 999 (b/c 95% of our data is comprised of those values)
#    - month = 'may' (month w/the highest amount of calls)
#
# Another option could be to add in more 'yes' samples from the full dataset to add more variance and increase the probability that event Y will occur.
